# %%
s="we are friends {}"
d=s.format("forever")
d

# %%
s="{} is {} sumanth"
f=s.format("My","Pavan")
f

# %%
s="{1} is {0} and {2}"
d=s.format(19,"pavan","young")
d

# %% [markdown]
# **Errors**

# %%
i=2
if i=2:      #Syntax error
    print("i is 2")

# %%
i=2
i=i/0    # runtime error

# %%
i=2+3/5    # logical error
print(i)

# %%
l=[1,2,3,4,5,6]
print(l[7])

# %%
import nupy

# %%
d={
    1:5,
    2:"hi"
}
print(d[3])

# %%
a=1
b=2
c=a+m

# %%
a=1
c=a+"HI"
c

# %%
try:
    a=1
    b=a/0
except Exception as e:
    print(e)

# %%
try:
    a=int(input("Enter a number:"))
    b=int(input("Enter a number:"))
    c=(a-b)/2
    print(c)
except:     # it is executed if there is exception in try block
    print("given wrong input")
print("the end")

# %%
try:
    a=int(input("Enter a number:"))
    b=int(input("Enter a number:"))
    c=2/(a-b)
    print(c)
except ZeroDivisionError:
    print(" the den is not zero")
except ValueError:
    print("Enter correct value")
print("The end")

# %%
try:
    a=int(input("Enter a number:"))
    b=int(input("Enter a number:"))
    c=2/(a-b)
    print(c)
except ZeroDivisionError:
    print(" the den is not zero")
except ValueError:
    print("Enter correct value")
print("The end")    # it  always executed whether exception is caught or not.

# %%
try:
    a=int(input("Enter a number:"))
    b=int(input("Enter a number:"))
    c=2/(a-b)
    print(c)
except ZeroDivisionError:
    print(" the den is not zero")
except ValueError:
    print("Enter correct value")
print("The end")

# %%
try:
    a=int(input("Enter a number:"))
    b=int(input("Enter a number:"))
    c=2/(a-b)
    print(c)
except ZeroDivisionError:
    print(" the den is not zero")
except ValueError:
    print("Enter correct value")
else:                                 # it is executed when exception is not raised.
    print("Thank you")
print("The end")

# %%
try:
    a=int(input("Enter a number:"))
    b=int(input("Enter a number:"))
    c=2/(a-b)
    print(c)
except ZeroDivisionError:         #it is executed when exception is not raised.
    print("Thank you")
    print(" the den is not zero")
except ValueError:
    print("Enter correct value")
else:                                 # it is executed when exception is not raised.
    print("Thank you")
finally:                                # it is always executed whther exception is raised or not
    print("always hi")
print("The end")

# %%
for i in range(9):
    print(i)
    if i==5:
        break
else:     # it only exceutes when break is not executed,in this case break is executed.
    print("ok")

# %%
n=int(input("Enter number:"))
for i in range(5):
    print(i)
    if i==n:
        break
else:
    print("it is executed when break is not encountered or executed")

# %%
n=int(input("Enter number:"))
for i in range(5):
    print(i)
    if i==n:
        break
else:
    print("it is executed when break is not encountered or executed")

# %% [markdown]
# **Comprehension** It acn be implemented for list,dictionary,set.

# %%
l=[i for i in range(9)]
l

# %%
l=[i for i in range(9) if i%2==0]
l

# %%
a,b=map(int,input().split())
print(a,b)

# %%
def add(x):
    return x**2
l=[1,3,4,5,6,7]
k=map(add,l)
print(list(k))

# %%
add=lambda x,y:x+y
print(add(1,2))

# %%
l=[1,2,3,4,5,6]
l=list(enumerate(l))   # it assigns a integer to every number starting from zero  and returns tuple such that(counter value ,list value)
print(l)
for  i in l:
    print(i)

# %%
l=[1,2,3,4,5,6]
l=list(enumerate(l,5))   # enumerate assigns a integer to every number starting from five  and returns tuple such that(counter value ,list value)
print(l)
for  i in l:
    print(i)

# %%
l=[1,2,3,4,5,6]
l= list(filter(lambda x:x%2==0, l))   # filter returns value that satisfy condition specified.
print(l)

# %%
 def fun(x):
        if x%2==0:
            return True
        else:
            return False
l=[1,2,3,4,5,6]
l= list(filter(fun, l))     # here we have used function instaed of lamda function.
print(l)

# %%
l=[1,2,3,4,5,6]
s=[i for i in l]
print(s)

# %%
l=[1,2,3,4,5,6]
s=[i for i in l if i%2==0] 
s

# %%
l=[1,2,3,4,5,6]
s=[i if i%2==0 else "No" for i in l]
s

# %%
dic={
    1:"pavan",
    2:"SUMANTH",
    3:"SAI"
}
d={i:j for i,j in dic.items()}
print(d)

# %%
dic={
    1:"pavan",
    2:"SUMANTH",
    3:"SAI"
}
d={i:len(j) for i,j in dic.items()  }
print(d)

# %%
dic={
    1:"pavan",
    2:"SUMANTH",
    3:"SAIR"
}
d={i:"Yes" for i,j in dic.items() if len(j)%2==0 }
print(d)

# %%
dic={
    1:"pavan",
    2:"SUMANTH",
    3:"SAIR"
}
d={i:"Yes" if len(j)%2==0 else "No" for i,j in dic.items()  }
print(d)

# %%
def fun(x,y):
    return x*y
l=[1,2,3,4,5,6]
l1=[1,2,3,4,5,6]
l=list(map(fun,l,l1))      # map takestwo two  positional arguments 
print(l)

# %%
l=["pavan","sai","krishna","sumanth"]
l=list(map(lambda x:len(x),l))
print(l)

# %% [markdown]
# **File operations**

# %%
f=open("../input/poetry/alicia-keys.txt")   # it open file

# %%
f.readline()    # it reads the file line by line every time you enter new line executed.

# %%
f.seek(0)    # it moves the pointer to first position (start) of file

# %%
f.read(3)    # it read specified no of charcaters from file

# %%
f.read(3)    # it reads specified no of characters from the current position  but not from start.

# %%
f.close()       # closes the file

# %%
f=open("pavan.txt",'w')    # it creates file if it does not exist if it exists it opens the file.

# %%
f.write("I am Pavan")   # it writes text into file and returns  no of how many characters in file

# %%
f.close()

# %%
f=open("pavan.txt")

# %%
f.read()

# %%
f.write("i am 21 years old")    # it overwites previous content in the file and replaces it with new content.And the  file contains only new content

# %%
f.close()

# %%
f=open("pavan.txt")

# %%
f.read()

# %%
f.close()

# %%
f=open("pavan.txt","a")   #opens the file in append mode.here the new content do not overwrite exoisting content but here new 
                          #content is appended at the end of the existing content.

# %%
f.write("I am sumanth")

# %%
f.close()

# %%
f=open("pavan.txt")

# %%
f.read()

# %%
f.close()

# %% [markdown]
# **To read or write unstructured data such as videos,images we will use rb and wb commands.**

# %%
img=open("../input/cifar10-pngs-in-folders/cifar10/train/bird/0001.png",'rb')  # it opens file in binary format

# %%
s=img.read()    # it reads image file that is present in binary format

# %%
bird=open("bird.png",'wb')    # it creates file

# %%
bird.write(s)     # it writes  binary dats that is stored in the s  into new file

# %%
bird.close()

# %%
img.close()

# %%
try:
    f=open("pavan.txt")
    1/0
    f.close()
except:                # file is not closed as there is an exception  occured f.close() is passed.it is not good to do like this.so we use finally to place f.close() irresepective of exception ooccured or not file will be closed.
    print("The execte block is executed when there is an exception")

# %%
f.readline()

# %%
try:
    f=open("pavan.txt")
    1/0
except:              # here file closed even when execption occured as f.close() placed in finally block.   
    print("The execte block is executed when there is an exception")
finally:
    f.close()

# %%
f.read()

# %%
with open("pavan.txt","w") as f:
    f.write("pavan sumanth")      # once we get out of the block  it is automatically closed we cannot read it.

# %%
f.read()

# %%
s=open("pavan.txt",'r')

# %%
s.read()

# %%
s.close()

# %%
import math
math.e

# %%
math.pi

# %%
math.ceil(3.4567)    # it gives next highest number.

# %%
round(3.456,1)     # it round the decimal part to no of points we specified.

# %%
math.floor(4.56)    # it gives lower number

# %%
abs(-5)  # it gives the positive number

# %%
math.trunc(3.456)   # it removes decimal points

# %%
math.pow(2,4)    # it gives power of variable
