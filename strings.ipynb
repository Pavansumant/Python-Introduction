# %%
a="I am pavan sumanth"
print(a)
type(a)

# %% [markdown]
# **string slicing**

# %%
len(a)

# %%
a[0:18]

# %%
a[5
 ]

# %%
for i in a:
    print(i)

# %% [markdown]
# **String methods**

# %%
b="pavan" # strings are immutable.so store changed string into new variable .
b=b.upper() #convert string into uppercase
b

# %%
b="pavan"
b=b.lower() #convert string into lowercase
b

# %%
b="pavan sumanth"
b=b.title() #convert string into title case i.e every word first letter into capitals
b

# %%
b="pavan"
b=b.isupper() #check whether string is in uppercase
b

# %%
b="pavan"
b=b.islower() #check whether string is in lowercase
b

# %%
b="Pavan"
b=b.swapcase() #changes cases of strings

# %%
a="I am pavan sumanth"
a=a.startswith("I") # checks whether string starts with given letter,word  or not
a

# %%
a="I am pavan sumanth"
a=a.endswith("Sumanth") # checks whether string ends with given letter,word  or not.variables are cass sensitive
a

# %%
a="123"
a=a.isalnum() #return true when string contains only alphabets,or only characters or both.
a

# %%
a="pavan123"
a=a.isalpha() #returns true when string contains alphabets
a

# %%
a="123"
a=a.isnumeric() #return true when string contains only numeric character
a

# %%
a='A'
ord(a) #returns unicode character of string

# %%
a=65
chr(a) #returns character

# %%
a="i am pavan sumanth"
a=a.capitalize()  # returns string with only first letter in capitals
a

# %%
a="I am pavan sumanth"
a=a.isascii()     # returns true if all characters in string are a-z,0-9.
a

# %%
a="I am pavan sumanth"
a=a.count("I")       #return count of specified parameter
a

# %%
name=input("Name:")
age=int(input("Age:"))    #it allows to format text
print("{} is {} years old".format(name,age))

# %%
a="I am pavan sumanth"
b="I-am-21-years-old"
a=a.split()
b=b.split("-")  #split string basedon separator given to method and returns list 
print(a)
print(b)

# %%
c=['I', 'am', '21', 'years', 'old']
c="-".join(c)
print(c)              #accepts iterable as parameter and returns string by joining all elements in iterable with separator given to it.

# %%
a="   I am pavan sumanth  "
b=a.strip()   # removes whitespaces at the beginning and ending of the string
c=a.lstrip()   # removes whitespaces at the beginning  of the string
d=a.rstrip()   # removes whitespaces at   ending of the string
print(b)
print(c)
print(d)

# %%
a="I am pavan sumanth"
a=a.split()
for i in a:
    print(i)

# %%
a="I am pavan sumanth"  #it gives the starting index of the given element it return -1 when element not found
i=a.find("am")
j=a.find('kl')

# %%
a.index("pavan")   
a.index('kl')#it gives the  starting index of given element  bu it return error when element not found
