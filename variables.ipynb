# %%
a=5
a

# %%
a=5
type(a)

# %%
a="Hello"
type(a)

# %%
a=5.6
type(a)

# %%
a="ABC123"
type(a)

# %%
a=1+3j
print(a)
type(a)

# %%
a="I am Pavan Sumanth"
print(a)
type(a)

# %%
a="It's raining outside"
print(a)

# %%
a=True
b=False
a & b # a and b

# %%
a,b=1,2
print(a,b,sep="\n")
print(a,b,end="\n")

# %%
a,b,c="hello",2,"sumanth"
print(a,b,c)

# %%
first_name="pavan"
last_name="sumanth"
name=first_name+" "+last_name
name_1=first_name+"\n"+last_name
print(name)
print(name_1)

# %%
a=3
b=5
c=a>b
print(c)
type(c)

# %%
a="5"
b="HI"
a=str(a) # convert integer to string 
print(a+b)
type(a)

# %%
a=1
b="p"
# a+b (cannot add integer and string )
a=str(a)
a+b

# %%
a=5
b=6
print("Before Swapping:",a,b)
c=a
a=b
b=c
print("After Swapping:",a,b)

# %% [markdown]
# **Implicit Conversion**

# %%
a=1
b=1.5
c=a+b
print(c)

# %% [markdown]
# **Explicit Conversion**

# %%
a=1
b=1.5
c=int(b)+a
c

# %% [markdown]
# **operators**

# %%
a=1
b=4
add=a+b
sub=a-b
mul=a*b
div=a/b
mod=a%b
print(add)
print(sub)
print(mul)
print(div)
print(mod)

# %%
a=1
b=2
print(a<b)
print(a>b)
print(a<=b)
print(a>=b)
print(a==b)
print(a!=b)

# %%
a=1
b=2
print(a and b)
print(a or b)
print(not a)

# %%
a=input("Enter your name:")
print(a)

# %%
a=int(input("Enter your age:"))
print(a)
