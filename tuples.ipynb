# %%
t=()
type(t)

# %%
t=tuple()
type(t)

# %% [markdown]
# Tuple can contain mutable elements such as dictionary,list. Tuple are immutable,ordered,dontain duplicates.

# %%
t=(1,3,7,"Hi",3.4)
t[1]
# Out:
# 3

# %%
t1=(1,2,3)
t2=([1,2,3,4])
a=(t1,t2)
print(a)

# %%
t[1]=4    #tuples are immutable
t

# %%
t[1:]  #slicing

# %%
t=(1,2,"HI",[3,4],{"name":"pavan","age":18},3.5)
print(t[3])
print(t[4])

# %%
t[3][0]

# %%
t[4]["name"]

# %% [markdown]
# **Zip Function is used to combine two lists and returns tuple of lists**

# %%
l=[1,2,3,4,5]
i=["hi","hello","Thanks","you",]
s=zip(l,i)
list(s)

# %%
l=[1,2,3,4,5]
i=["hi","hello","Thanks","you",5]
s=zip(l,i)
list(s)

# %% [markdown]
# **Methods**

# %%
t1=("HI",5.5,6,1,"j")
len(t)

# %%
t2=(7,9)
t=t1+t2    # merge two tuples using addition operation
t

# %%
t1.index(6)

# %%
del t1    # entire tuple can be deleted but individual element cannot be deleted as it is immutable.

# %%
t1
